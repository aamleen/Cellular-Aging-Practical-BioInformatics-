# %% [markdown]
# <a href="https://colab.research.google.com/github/aamleen/PB-Project/blob/main/Cell_Life_Visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
# %matplotlib inline
from google.colab import files
import io

# %%
"""
cell_df1=pd.read_csv('dataset1.csv')
cell_df1
cell_df3=pd.read_csv('dataset3.csv')
cell_df3
cell_df2=pd.read_csv('dataset2.csv')
cell_df2
"""
# Out:
# "\ncell_df1=pd.readcsv('dataset1.csv')\ncell_df1\ncell_df3=pd.readcsv('dataset3.csv')\ncell_df3\ncell_df2=pd.readcsv('dataset2.csv')\ncell_df2\n"

# %%
uploaded=files.upload()
cell_df1=pd.read_csv(io.BytesIO(uploaded['dataset1.csv']))
cell_df1
# Out:
#      <input type="file" id="files-42bfc649-1d89-41e0-9620-cd48776bc01e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-42bfc649-1d89-41e0-9620-cd48776bc01e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataset1.csv to dataset1 (1).csv
#          Group                             Species Body Temperature (oC )  \
# 0      mammals                   Ammotragus lervia                     37
# 1      mammals                          Bos Taurus                   38.3
# 2      mammals                    Canis familiaris                   38.9
# 3      mammals                        Capra hirkus                   39.1
# 4      mammals    Cavia aperea Erx. Var. Procellus                    39a
# 5      mammals           Cervus elaphus canadensis                   38.9
# 6      mammals                Cervus nippon nippon                   37.1
# 7      mammals             Choloepus didactylus L.                  34.4b
# 8      mammals  Citellus tridecemlineatus Mitchill                   38.9
# 9      mammals                Dasypus novemcincius                   34.9
# 10     mammals    Didelphis marsupialis virginiana                     35
# 11     mammals                      Equis caballus                   37.6
# 12     mammals                 Erinaceus europaeus                   33.9
# 13     mammals                         Felis catus                   38.6
# 14     mammals                           Glis glis                   37.7
# 15     mammals                Glossophaga soricina                   24.5
# 16     mammals    Hemitragus jemlahicus jemlahicus                     37
# 17     mammals                        Homo sapiens                     37
# 18         NaN                                 NaN                    NaN
# 19     mammals                       Lama guanicos                  38.7c
# 20     mammals              Leptonycteris curasoae                   24.5
# 21     mammals                      Lutreola vison                   37.3
# 22     mammals                      Macaca mullata                     37
# 23     mammals              Meriones unguiacalatus                   38.2
# 24     mammals                        Mus musculus                   36.9
# 25     mammals                 Odocoileus hemionna                    39d
# 26     mammals              Odocoileus virginianus                     39
# 27     mammals              Oryctolagus corniculus                     39
# 28     mammals                          Ovis aries                   39.1
# 29     mammals                   Rattus norvegicus                   37.3
# 30         NaN                                 NaN                    NaN
# 31       birds                       Columba livia                     40
# 32       birds               Corvus brachyrhynchos                   41.5
# 33         NaN                                 NaN                    NaN
# 34       birds          Coturnix coturnix japonica                   40.8
# 35       birds                  Dendroica coronata                   40.5
# 36       birds                       Gallus gallus                   41.7
# 37       birds                   Passer domesticus                   43.5
# 38       birds                  Pygoscelis adeliae                   38.2
# 39       birds                 Taeniopygia guttata                     41
# 40         NaN                                 NaN                    NaN
# 41    reptiles          Alligator mississippiensis                     31
# 42    reptiles          Alligator mississippiensis                   16.5
# 43    reptiles                     Caretta caretta                   26.5
# 44    reptiles                     Caretta caretta                   26.5
# 45    reptiles                  Elapha o. obsoleta                     20
# 46         NaN                                 NaN                    NaN
# 47  amphibians         Rana catesbeiana (tadpoles)                     25
# 48  amphibians                        Rana pipiens                     25
# 49  amphibians                   Taricha granulosa                     14
# 50         NaN                                 NaN                    NaN
# 51      fishes       Carassius auratus langsdorfii                     25
# 52      fishes                    Crassius auratus                   19.5
# 53      fishes                 Oncorhynchus mykiss                    12e
# 54      fishes       Pterygoplichthys disjunctivus                     25
# 55      fishes                         Tinca tinca                     18
#
#     Body Mass (kg)  Average Cell Lifespan (d)  \
# 0          45.5000                      147.0
# 1         404.0000                      130.0
# 2          14.5000                      100.0
# 3          31.8000                      115.0
# 4           0.7150                       80.0
# 5         275.0000                      149.0
# 6          55.0000                      159.0
# 7           9.0000                      113.5
# 8           0.1930                       94.6
# 9           4.4000                       72.0
# 10          3.7000                       74.0
# 11        486.0000                      143.0
# 12          0.6720                       91.2
# 13          3.6000                       72.5
# 14          0.1200                       91.0
# 15          0.0102                      181.8
# 16         35.3000                      156.0
# 17         65.0000                      110.0
# 18             NaN                        NaN
# 19         72.0000                      201.0
# 20          0.0236                      173.1
# 21          0.7950                       92.2
# 22          6.5000                       95.8
# 23          0.0660                       43.0
# 24          0.0257                       43.0
# 25         32.0000                       95.0
# 26         73.7000                      127.0
# 27          3.2000                       57.0
# 28         64.0000                      135.0
# 29          0.3020                       56.0
# 30             NaN                        NaN
# 31          0.4150                       35.0
# 32          0.4160                       43.0
# 33             NaN                        NaN
# 34          0.1126                       18.0
# 35          0.0115                       15.7
# 36          3.4000                       30.0
# 37          0.0220                       27.8
# 38          4.9000                       31.4
# 39          0.0160                       19.3
# 40             NaN                        NaN
# 41          2.5000                      256.3
# 42          2.5000                     1135.2
# 43          0.2088                       40.1
# 44          0.0198                       76.9
# 45          0.6250                      122.0
# 46             NaN                        NaN
# 47          0.0195                       98.7
# 48          0.0780                      172.0
# 49          0.0070                       86.0
# 50             NaN                        NaN
# 51          0.2250                       73.6
# 52          0.0091                      111.8
# 53          1.4000                      500.0
# 54          0.0510                      127.8
# 55          0.1300                      150.0
#
#                                            Source  Real Life Span
# 0                                      Vacha 1983            20.0
# 1              White and Seymour 2003, Vacha 1983            20.0
# 2              White and Seymour 2003, Vacha 1983            16.0
# 3              White and Seymour 2003, Vacha 1983            18.0
# 4                  Clarke et al. 2010, Vacha 1983             8.0
# 5              White and Seymour 2003, Vacha 1983            25.0
# 6                  Suzuki et al. 2001, Vacha 1983            18.0
# 7                  Clarke et al. 2010, Vacha 1983            28.0
# 8                           Hock 1960, Vacha 1983             8.0
# 9                       Johansen 1961, Vacha 1983            20.0
# 10             White and Seymour 2003, Vacha 1983             4.0
# 11             White and Seymour 2003, Vacha 1983            30.0
# 12                Webb & Ellison 1998, Vacha 1983             8.0
# 13             White and Seymour 2003, Vacha 1983            14.0
# 14                 Clarke et al. 2010, Vacha 1983             9.0
# 15     White and Seymour 2003, Voight et al. 2003            10.0
# 16                                     Vacha 1983            14.0
# 17     White and Seymour 2003, Smith et al. 2003,            66.0
# 18         Rodnan et al. 1967; Kurata et al. 1993             NaN
# 19                 Clarke et al. 2010, Vacha 1983            28.0
# 20     White and Seymour 2003, Voight et al. 2003            10.0
# 21                      Youngman 1990, Vacha 1983            30.0
# 22             White and Seymour 2003, Vacha 1983            30.0
# 23             White and Seymour 2003, Vacha 1983             3.0
# 24             White and Seymour 2003, Vacha 1983             2.0
# 25                 Clarke et al. 2010, Vacha 1983            22.0
# 26                 Clarke et al. 2010, Vacha 1983            16.0
# 27             White and Seymour 2003, Vacha 1983             9.0
# 28             White and Seymour 2003, Vacha 1983            20.0
# 29             White and Seymour 2003, Vacha 1983             2.0
# 30                                            NaN             NaN
# 31                             Rodnan et al. 1957             6.0
# 32    Baldwin & Kendeigh 1932 as in Verbeek 1995,             8.0
# 33                            Hobson & Clark 1993             NaN
# 34         Freeman 1970, Nirmalan & Robinson 1973             6.0
# 35           Yarboroug 1971, Podlesak et al. 2005             7.0
# 36     White and Seymour 2003, Rodnan et al. 1957            20.0
# 37     McNab 1966, Bauchinger and McWilliams 2009            10.0
# 38               McNab 1966, Beaulieu et al. 2010            15.0
# 39                 Bauchinger and McWilliams 2009             5.0
# 40                                            NaN             NaN
# 41   Cline & Waldman 1962a, Cline & Waldman 1962b            50.0
# 42   Cline & Waldman 1962a, Cline & Waldman 1962b            50.0
# 43                              Reich et al. 2008            33.0
# 44                              Reich et al. 2008            33.0
# 45               Marvin 1963, Baeyens et al. 1980            34.0
# 46                                            NaN             NaN
# 47            Forman & Just 1975, Kupferberg 1997             8.0
# 48                          Cline & Waldman 1962b             8.0
# 49                           Freidman et al. 1969            15.0
# 50                                            NaN             NaN
# 51  Fischer et al. 1998, Nakanishi & Ototake 1999            30.0
# 52                           Houston & Murad 1995            30.0
# 53                              Avery et al. 1992             8.0
# 54                          German and Miles 2010             5.0
# 55                              Hevesy et al 1964            10.0

# %%
uploaded=files.upload()
cell_df2=pd.read_csv(io.BytesIO(uploaded['dataset2.csv']),encoding='ISO-8859-1')
cell_df2
# Out:
#      <input type="file" id="files-47eaedb8-c860-469d-af8a-51a733137c7d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-47eaedb8-c860-469d-af8a-51a733137c7d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataset2.csv to dataset2 (5).csv
# (       Group                           Species    Cell Type  \
#  0    mammals  Didelphis marsupialis virginiana  erythrocyte
#  1        NaN                               NaN          NaN
#  2        NaN                               NaN          NaN
#  3    mammals               Erinaceus europaeus  erythrocyte
#  4        NaN                               NaN          NaN
#  ..       ...                               ...          ...
#  171      NaN                               NaN          NaN
#  172      NaN                               NaN          NaN
#  173   fishes     Carassius auratus langsdorfii     monocyte
#  174      NaN                               NaN          NaN
#  175      NaN                               NaN          NaN
#
#      Body Temperature (oC )  Body Mass (kg)  Average Cell Lifespan (d)  \
#  0                       35            3.70                       74.0
#  1                      NaN             NaN                        NaN
#  2                      NaN             NaN                        NaN
#  3                    33.93            0.67                       91.2
#  4                      NaN             NaN                        NaN
#  ..                     ...             ...                        ...
#  171                    NaN             NaN                        NaN
#  172                    NaN             NaN                        NaN
#  173                     25            0.23                       95.0
#  174                    NaN             NaN                        NaN
#  175                    NaN             NaN                        NaN
#
#      Cell Volume (um3) Cell Dimensions (um)                  Sources  \
#  0                  77                  NaN  White and Seymour 2003,
#  1                 NaN                  NaN              Vacha 1983,
#  2                 NaN                  NaN  genomesize.com/cellsize
#  3                  41                  NaN     Webb & Ellison 1998,
#  4                 NaN                  NaN              Vacha 1983,
#  ..                ...                  ...                      ...
#  171               NaN                  NaN            Rey Vazquez &
#  172               NaN                  NaN            Guerrero 2007
#  173              904k               D: 12l     Fischer et al. 1998,
#  174               NaN                  NaN            Rey Vazquez &
#  175               NaN                  NaN            Guerrero 2007
#
#       Real Life Span
#  0               4.0
#  1               NaN
#  2               NaN
#  3               8.0
#  4               NaN
#  ..              ...
#  171             NaN
#  172             NaN
#  173            30.0
#  174             NaN
#  175             NaN
#
#  [176 rows x 10 columns],)

# %%
uploaded=files.upload()
cell_df3=pd.read_csv(io.BytesIO(uploaded['dataset3.csv']),encoding="ISO-8859-1")
cell_df3
# Out:
#      <input type="file" id="files-f7237e7a-ffa7-4dc8-ac25-13cfe03280c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f7237e7a-ffa7-4dc8-ac25-13cfe03280c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataset3.csv to dataset3 (1).csv
#          Group                 Species               Cell Type  BodyMass (kg)  \
# 0      mammals              Bos Taurus  young adult fibroblast     725.000000
# 1      mammals              Bos Taurus  adult parathyroid cell     725.000000
# 2      mammals        Canis familiaris  young adult fibroblast      10.800000
# 3      mammals        Eptesicus fuscus  young adult fibroblast       0.022000
# 4      mammals             Felis catus  young adult fibroblast       4.000000
# 5      mammals         Gorilla gorilla  young adult fibroblast     155.000000
# 6      mammals   Heterocephalus glaber  young adult fibroblast       0.042000
# 7      mammals            Homo sapiens        adult osteoblast      65.000000
# 8      mammals            Homo sapiens  young adult fibroblast      70.000000
# 9      mammals    Mesocricetus auratus            adult dermis       0.100000
# 10     mammals            Mus musculus  young adult fibroblast       0.022500
# 11     mammals  Peromyscus maniculatus  young adult fibroblast       0.026500
# 12     mammals       Rattus norvegicus  young adult fibroblast       0.330000
# 13     mammals    Sciurus carolinensis  young adult fibroblast       0.520000
# 14         NaN                     NaN                     NaN            NaN
# 15       birds           Gallus gallus       embryo fibroblast       3.400000
# 16         NaN                     NaN                     NaN            NaN
# 17    reptiles    Testudo elephantopus           adult T1 cell       7.900000
# 18         NaN                     NaN                     NaN            NaN
# 19  amphibians     Rana  nigromaculata     froglet melanophore       0.025000
# 20  amphibians        Rana catesbeiana            melanophores       0.147260
# 21         NaN                     NaN                     NaN            NaN
# 22      fishes     Cynoscion nebulosus            adult muscle       0.423799
# 23         NaN                     NaN                     NaN            NaN
# 24      fishes         Oryzias latipes              fibroblast       0.000527
#
#     Replicative Lifespan (d)                                    Sources  \
# 0                      74.00                      Lorenzini et al. 2005
# 1                     140.00  Brandi et al. 1986, Lorenzini et al. 2005
# 2                      30.00                      Lorenzini et al. 2005
# 3                      14.00                      Lorenzini et al. 2005
# 4                      24.00                      Lorenzini et al. 2005
# 5                      81.00                      Lorenzini et al. 2005
# 6                      16.00                      Lorenzini et al. 2005
# 7                      31.00                         Kassem et al. 1997
# 8                      40.00                      Lorenzini et al. 2005
# 9                      12.45                          Bruce et. al 1986
# 10                      8.00                      Lorenzini et al. 2005
# 11                     11.00                      Lorenzini et al. 2005
# 12                     19.00                      Lorenzini et al. 2005
# 13                     10.00                      Lorenzini et al. 2005
# 14                       NaN                                        NaN
# 15                     32.50              Lima 1972, Rodnan et al. 1957
# 16                       NaN                                        NaN
# 17                    114.00                             Goldstein 1974
# 18                       NaN                                        NaN
# 19                     12.80           Okumoto 2001, Konsue et al. 2001
# 20                     69.00       Kondo and Ide 1983, Wang et al. 2007
# 21                       NaN                                        NaN
# 22                    125.00                  Middlebrooks et al. 1979,
# 23                       NaN                      Johnson & Seaman 1986
# 24                      6.90      Komura et l. 1987, Davies et al. 2002
#
#     Real Life Span
# 0             20.0
# 1             20.0
# 2             16.0
# 3             19.0
# 4             14.0
# 5             40.0
# 6             30.0
# 7             66.0
# 8             66.0
# 9              2.0
# 10             2.0
# 11             8.0
# 12             2.0
# 13            13.0
# 14             NaN
# 15            20.0
# 16             NaN
# 17           100.0
# 18             NaN
# 19             8.0
# 20             8.0
# 21             NaN
# 22            10.0
# 23             NaN
# 24             2.0
